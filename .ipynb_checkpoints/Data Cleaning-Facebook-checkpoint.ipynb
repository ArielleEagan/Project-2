# %%
#Import dependencies
import pandas as pd
import requests

#API pull for latest salary info from www.levels.fyi
salaryData = requests.get('https://www.levels.fyi/js/salaryData.json').json()
salary_df = pd.DataFrame(salaryData)

# %%
#raw table preview
salary_df.head(10)
# Out:
#             timestamp    company level                         title  \
# 0   6/7/2017 11:33:27     Oracle    L3               Product Manager
# 1  6/10/2017 17:11:29       eBay  SE 2             Software Engineer
# 2  6/11/2017 14:53:57     Amazon    L7               Product Manager
# 3  6/14/2017 21:22:25  Microsoft    64  Software Engineering Manager
# 4  6/16/2017 10:44:01     Amazon    L5             Software Engineer
# 5   6/17/2017 0:23:14      Apple    M1  Software Engineering Manager
# 6  6/20/2017 10:58:51  Microsoft    60             Software Engineer
# 7  6/20/2017 18:49:59     Amazon    L5             Software Engineer
# 8  6/21/2017 17:27:47  Microsoft    63             Software Engineer
# 9  6/22/2017 12:37:51  Microsoft    65  Software Engineering Manager
#
#   totalyearlycompensation               location yearsofexperience  \
# 0                     127       Redwood City, CA               1.5
# 1                     100      San Francisco, CA                 5
# 2                     310            Seattle, WA                 8
# 3                     200            Redmond, WA                 9
# 4                     173  Vancouver, BC, Canada                11
# 5                     372          Sunnyvale, CA                 7
# 6                     157      Mountain View, CA                 5
# 7                     190            Seattle, WA                 3
# 8                     208            Seattle, WA               8.5
# 9                     300            Redmond, WA                15
#
#   yearsatcompany tag basesalary stockgrantvalue  bonus gender otherdetails  \
# 0            1.5            107              20     10
# 1              3
# 2              0            155
# 3              9         169000          100000  30000
# 4              1         120000               0  53000
# 5              5            157             180     35
# 6              3
# 7              3         110000           80000
# 8            8.5
# 9             11            180              65     55
#
#   cityid dmaid  rowNumber
# 0   7392   807          1
# 1   7419   807          2
# 2  11527   819          3
# 3  11521   819          5
# 4   1320     0          6
# 5   7472   807          7
# 6   7322   807          9
# 7  11527   819         10
# 8  11527   819         11
# 9  11521   819         12

# %%
#dropping columns that are not relevant to project
salary_df = salary_df.drop(['cityid', 'dmaid','rowNumber','otherdetails',], axis=1)
salary_df.head(10)
# Out:
#             timestamp    company level                         title  \
# 0   6/7/2017 11:33:27     Oracle    L3               Product Manager
# 1  6/10/2017 17:11:29       eBay  SE 2             Software Engineer
# 2  6/11/2017 14:53:57     Amazon    L7               Product Manager
# 3  6/14/2017 21:22:25  Microsoft    64  Software Engineering Manager
# 4  6/16/2017 10:44:01     Amazon    L5             Software Engineer
# 5   6/17/2017 0:23:14      Apple    M1  Software Engineering Manager
# 6  6/20/2017 10:58:51  Microsoft    60             Software Engineer
# 7  6/20/2017 18:49:59     Amazon    L5             Software Engineer
# 8  6/21/2017 17:27:47  Microsoft    63             Software Engineer
# 9  6/22/2017 12:37:51  Microsoft    65  Software Engineering Manager
#
#   totalyearlycompensation               location yearsofexperience  \
# 0                     127       Redwood City, CA               1.5
# 1                     100      San Francisco, CA                 5
# 2                     310            Seattle, WA                 8
# 3                     200            Redmond, WA                 9
# 4                     173  Vancouver, BC, Canada                11
# 5                     372          Sunnyvale, CA                 7
# 6                     157      Mountain View, CA                 5
# 7                     190            Seattle, WA                 3
# 8                     208            Seattle, WA               8.5
# 9                     300            Redmond, WA                15
#
#   yearsatcompany tag basesalary stockgrantvalue  bonus gender
# 0            1.5            107              20     10
# 1              3
# 2              0            155
# 3              9         169000          100000  30000
# 4              1         120000               0  53000
# 5              5            157             180     35
# 6              3
# 7              3         110000           80000
# 8            8.5
# 9             11            180              65     55

# %%
#converting to float to allow for summary stats
salary_df["totalyearlycompensation"] = pd.to_numeric(salary_df["totalyearlycompensation"])
salary_df["yearsofexperience"] = pd.to_numeric(salary_df["yearsofexperience"])
salary_df["yearsatcompany"] = pd.to_numeric(salary_df["yearsatcompany"])
salary_df["basesalary"] = pd.to_numeric(salary_df["basesalary"])
salary_df["stockgrantvalue"] = pd.to_numeric(salary_df["stockgrantvalue"])
salary_df["bonus"] = pd.to_numeric(salary_df["bonus"])

#coverting timestamp from object to datetime
salary_df['timestamp'] =  pd.to_datetime(salary_df['timestamp'], infer_datetime_format=True)

# %%
# Create separate cols for city, state and country
def split_location(location):
    items = location.split(', ')
    city = items[0]
    state = items[1]
    
    if len(items)==2:
        country = 'US'
    elif len(items)==3:
        country = items[2].strip()
    elif len(items)==4:
        country = ', '.join([i.strip() for i in items[2:]])
    else:
        country = None
        print(location)
        
    return [city, state, country]

# %%
salary_df['loc_items'] = salary_df.location.apply(lambda x: split_location(x))
salary_df['city'] = salary_df.loc_items.apply(lambda x: x[0])
salary_df['state'] = salary_df.loc_items.apply(lambda x: x[1])
salary_df['country'] = salary_df.loc_items.apply(lambda x: x[2])

# %%
salary_df.head()
# Out:
#             timestamp    company level                         title  \
# 0 2017-06-07 11:33:27     Oracle    L3               Product Manager
# 1 2017-06-10 17:11:29       eBay  SE 2             Software Engineer
# 2 2017-06-11 14:53:57     Amazon    L7               Product Manager
# 3 2017-06-14 21:22:25  Microsoft    64  Software Engineering Manager
# 4 2017-06-16 10:44:01     Amazon    L5             Software Engineer
#
#    totalyearlycompensation               location  yearsofexperience  \
# 0                    127.0       Redwood City, CA                1.5
# 1                    100.0      San Francisco, CA                5.0
# 2                    310.0            Seattle, WA                8.0
# 3                    200.0            Redmond, WA                9.0
# 4                    173.0  Vancouver, BC, Canada               11.0
#
#    yearsatcompany tag  basesalary  stockgrantvalue    bonus gender  \
# 0             1.5           107.0             20.0     10.0
# 1             3.0             NaN              NaN      NaN
# 2             0.0           155.0              NaN      NaN
# 3             9.0        169000.0         100000.0  30000.0
# 4             1.0        120000.0              0.0  53000.0
#
#                  loc_items           city state country
# 0   [Redwood City, CA, US]   Redwood City    CA      US
# 1  [San Francisco, CA, US]  San Francisco    CA      US
# 2        [Seattle, WA, US]        Seattle    WA      US
# 3        [Redmond, WA, US]        Redmond    WA      US
# 4  [Vancouver, BC, Canada]      Vancouver    BC  Canada

# %%
# droping location column  
salary_df = salary_df.drop(['location','loc_items'], axis=1)
salary_df.head(10)
# Out:
#             timestamp    company level                         title  \
# 0 2017-06-07 11:33:27     Oracle    L3               Product Manager
# 1 2017-06-10 17:11:29       eBay  SE 2             Software Engineer
# 2 2017-06-11 14:53:57     Amazon    L7               Product Manager
# 3 2017-06-14 21:22:25  Microsoft    64  Software Engineering Manager
# 4 2017-06-16 10:44:01     Amazon    L5             Software Engineer
# 5 2017-06-17 00:23:14      Apple    M1  Software Engineering Manager
# 6 2017-06-20 10:58:51  Microsoft    60             Software Engineer
# 7 2017-06-20 18:49:59     Amazon    L5             Software Engineer
# 8 2017-06-21 17:27:47  Microsoft    63             Software Engineer
# 9 2017-06-22 12:37:51  Microsoft    65  Software Engineering Manager
#
#    totalyearlycompensation  yearsofexperience  yearsatcompany tag  basesalary  \
# 0                    127.0                1.5             1.5           107.0
# 1                    100.0                5.0             3.0             NaN
# 2                    310.0                8.0             0.0           155.0
# 3                    200.0                9.0             9.0        169000.0
# 4                    173.0               11.0             1.0        120000.0
# 5                    372.0                7.0             5.0           157.0
# 6                    157.0                5.0             3.0             NaN
# 7                    190.0                3.0             3.0        110000.0
# 8                    208.0                8.5             8.5             NaN
# 9                    300.0               15.0            11.0           180.0
#
#    stockgrantvalue    bonus gender           city state country
# 0             20.0     10.0          Redwood City    CA      US
# 1              NaN      NaN         San Francisco    CA      US
# 2              NaN      NaN               Seattle    WA      US
# 3         100000.0  30000.0               Redmond    WA      US
# 4              0.0  53000.0             Vancouver    BC  Canada
# 5            180.0     35.0             Sunnyvale    CA      US
# 6              NaN      NaN         Mountain View    CA      US
# 7          80000.0      NaN               Seattle    WA      US
# 8              NaN      NaN               Seattle    WA      US
# 9             65.0     55.0               Redmond    WA      US

# %%
#isolating US data for further exploration
us_df = salary_df[salary_df.country=='US'].copy()

# %%
#isolating us data to data scientist titles
us_df = us_df[us_df.title=='Data Scientist'].copy()
us_df
# Out:
#                 timestamp              company              level  \
# 745   2018-06-05 14:06:30             LinkedIn             Senior
# 772   2018-06-08 00:29:47               Amazon                 L4
# 776   2018-06-08 09:49:25            Microsoft                 64
# 782   2018-06-08 17:55:09                 ebay                 26
# 796   2018-06-10 19:39:35              Twitter              Staff
# ...                   ...                  ...                ...
# 62569 2021-08-16 16:17:19                  IBM                 L5
# 62578 2021-08-16 17:08:58  Booz Allen Hamilton  Senior Consultant
# 62600 2021-08-16 21:02:37                Xandr                 L1
# 62610 2021-08-16 22:19:48             Facebook                 L4
# 62636 2021-08-17 07:55:47                 AT&T          Principal
#
#                 title  totalyearlycompensation  yearsofexperience  \
# 745    Data Scientist                    233.0                4.0
# 772    Data Scientist                    140.0                2.0
# 776    Data Scientist                    218.0               11.0
# 782    Data Scientist                    180.0               10.0
# 796    Data Scientist                    500.0                4.0
# ...               ...                      ...                ...
# 62569  Data Scientist                    145.0                6.0
# 62578  Data Scientist                    110.0                0.0
# 62600  Data Scientist                    120.0                1.0
# 62610  Data Scientist                    233.0                2.0
# 62636  Data Scientist                    175.0                9.0
#
#        yearsatcompany               tag  basesalary  stockgrantvalue  bonus  \
# 745               0.0     Data Analysis       162.0            220.0   10.0
# 772               2.0                       92000.0          48000.0    NaN
# 776              11.0           ML / AI       165.0             28.0   23.0
# 782               5.0                           NaN              NaN    NaN
# 796               4.0           ML / AI       200.0            280.0   20.0
# ...               ...               ...         ...              ...    ...
# 62569             5.0              Data       140.0              0.0    5.0
# 62578             0.0           General       110.0              0.0    0.0
# 62600             0.0           General       110.0              0.0   10.0
# 62610             2.0  Data Engineering       157.0             60.0   16.0
# 62636             7.0           general       155.0              0.0   20.0
#
#        gender           city state country
# 745      Male  San Francisco    CA      US
# 772      Male        Seattle    WA      US
# 776      Male        Seattle    WA      US
# 782    Female       San Jose    CA      US
# 796      Male  San Francisco    CA      US
# ...       ...            ...   ...     ...
# 62569    Male       New City    NY      US
# 62578    Male    West McLean    VA      US
# 62600    Male       Portland    OR      US
# 62610    Male     Menlo Park    CA      US
# 62636                Atlanta    GA      US
#
# [2227 rows x 15 columns]

# %%
#exploring us/datascience/IL at amazon
fb_df = us_df[us_df.company=='Facebook'].copy()
fb_df
# Out:
#                 timestamp   company level           title  \
# 858   2018-06-17 11:39:38  Facebook     5  Data Scientist
# 971   2018-07-05 13:43:39  Facebook   IC5  Data Scientist
# 1666  2018-09-06 00:50:18  Facebook   IC4  Data Scientist
# 1864  2018-09-17 15:37:28  Facebook    L5  Data Scientist
# 2766  2018-10-28 16:36:57  Facebook   IC3  Data Scientist
# ...                   ...       ...   ...             ...
# 61309 2021-08-06 11:08:11  Facebook   IC4  Data Scientist
# 62109 2021-08-12 21:54:41  Facebook   L5   Data Scientist
# 62244 2021-08-13 16:22:47  Facebook    M2  Data Scientist
# 62344 2021-08-14 08:07:55  Facebook    M2  Data Scientist
# 62610 2021-08-16 22:19:48  Facebook    L4  Data Scientist
#
#        totalyearlycompensation  yearsofexperience  yearsatcompany  \
# 858                      370.0                8.0            3.00
# 971                      225.0               11.0            6.00
# 1666                     200.0                5.0            0.25
# 1864                     240.0               10.0            1.00
# 2766                     193.0                1.0            0.00
# ...                        ...                ...             ...
# 61309                    302.0                9.0            3.00
# 62109                    334.0                4.0            2.00
# 62244                    700.0               16.0            2.00
# 62344                    631.0               11.0            0.00
# 62610                    233.0                2.0            2.00
#
#                         tag  basesalary  stockgrantvalue  bonus  gender  \
# 858                               190.0            140.0   40.0    Male
# 971                               155.0              NaN    NaN
# 1666         Infrastructure       150.0             35.0   15.0
# 1864             Full Stack       171.0             45.0   24.0
# 2766                ML / AI         NaN              NaN    NaN
# ...                     ...         ...              ...    ...     ...
# 61309      Data Engineering       161.0            125.0   16.0  Female
# 62109               General       182.0            125.0   27.0    Male
# 62244  Product Data Science       255.0            375.0   70.0    Male
# 62344               General       275.0            287.0   69.0    Male
# 62610      Data Engineering       157.0             60.0   16.0    Male
#
#                 city state country
# 858          Seattle    WA      US
# 971       Menlo Park    CA      US
# 1666      Menlo Park    CA      US
# 1864         Seattle    WA      US
# 2766   San Francisco    CA      US
# ...              ...   ...     ...
# 61309     Menlo Park    CA      US
# 62109       New York    NY      US
# 62244     Menlo Park    CA      US
# 62344       New York    NY      US
# 62610     Menlo Park    CA      US
#
# [173 rows x 15 columns]

# %%
#exploring targeted results for amazon levels reporting
fb_df.level.value_counts()
# Out:
# IC4                          50
# IC5                          39
# IC3                          16
# IC6                          14
# L4                           13
# E4                           11
# L5                            7
# E5                            4
# E3                            3
# L3                            3
# L5                            2
# M2                            2
# E6                            2
# L5 Product Growth Analyst     1
# 6                             1
# IC7                           1
# 5                             1
# M1                            1
# l4                            1
# L6                            1
# Name: level, dtype: int64

# %%
#comparing medians for insights on compareable levels
fb_levels_df = fb_df.groupby(['level']).agg({'totalyearlycompensation':'median', 'basesalary':'median', 'yearsofexperience':'median', 'yearsatcompany':'median',
                                                'stockgrantvalue':'median', 'bonus':'median'  })
fb_levels_df
# Out:
#                            totalyearlycompensation  basesalary  \
# level
# 5                                            370.0       190.0
# 6                                            338.0       216.0
# E3                                           157.0       120.0
# E4                                           230.0       152.5
# E5                                           337.5       190.0
# E6                                           482.5       216.5
# IC3                                          175.0       125.0
# IC4                                          218.5       151.5
# IC5                                          295.0       182.0
# IC6                                          385.0       218.0
# IC7                                          740.0       270.0
# L3                                           165.0       115.0
# L4                                           211.0       155.0
# L5                                           300.0       185.0
# L5                                           317.0       191.0
# L5 Product Growth Analyst                    280.0       190.0
# L6                                           464.0       220.0
# M1                                           412.0       210.0
# M2                                           665.5       265.0
# l4                                           220.0       148.0
#
#                            yearsofexperience  yearsatcompany  stockgrantvalue  \
# level
# 5                                        8.0            3.00            140.0
# 6                                       10.0            0.00             80.0
# E3                                       0.0            0.00             25.0
# E4                                       3.0            0.00             55.0
# E5                                       8.0            3.00            100.0
# E6                                      15.0            2.75            217.5
# IC3                                      2.0            1.00             30.0
# IC4                                      3.5            1.00             46.5
# IC5                                      7.0            2.00             86.5
# IC6                                     10.0            3.00            130.0
# IC7                                     10.0            4.00            400.0
# L3                                       0.0            0.00             25.0
# L4                                       3.0            1.00             41.0
# L5                                       7.0            1.00             81.0
# L5                                       4.0            1.50            102.5
# L5 Product Growth Analyst                8.0            2.00             62.0
# L6                                       8.0            5.00            200.0
# M1                                      10.0            4.00            144.0
# M2                                      13.5            1.00            331.0
# l4                                       5.0            2.00             50.0
#
#                            bonus
# level
# 5                           40.0
# 6                           42.0
# E3                          12.0
# E4                          16.0
# E5                          30.0
# E6                          48.5
# IC3                         11.0
# IC4                         16.0
# IC5                         27.0
# IC6                         43.5
# IC7                         70.0
# L3                          15.0
# L4                          16.0
# L5                          29.0
# L5                          26.0
# L5 Product Growth Analyst   29.0
# L6                          44.0
# M1                          57.0
# M2                          69.5
# l4                          20.0

# %%
#Correcting 5 to E5 as they have similar basesalary/bonus
fb_df.replace('5', 'E5', inplace=True)
#Correcting 6 to E6 as they have similar basesalary/bonus
fb_df.replace('6', 'E6', inplace=True)
#Correcting E4 to IC4 as they have similar basesalary/bonus
fb_df.replace('E4', 'IC4', inplace=True)
#Correcting E5 to IC5 as they have similar basesalary/bonus
fb_df.replace('E5', 'IC5', inplace=True)
#Correcting E6 to IC6 as they have similar basesalary/bonus
fb_df.replace('E6', 'IC6', inplace=True)

# %%
#exploring targeted results for amazon levels reporting
fb_df.level.value_counts()
# Out:
# IC4                          61
# IC5                          44
# IC6                          17
# IC3                          16
# L4                           13
# L5                            7
# L3                            3
# E3                            3
# L5                            2
# M2                            2
# l4                            1
# M1                            1
# IC7                           1
# L6                            1
# L5 Product Growth Analyst     1
# Name: level, dtype: int64

# %%
#comparing medians for insights on compareable levels
fb_levels_df = fb_df.groupby(['level']).agg({'totalyearlycompensation':'median', 'basesalary':'median', 'yearsofexperience':'median', 'yearsatcompany':'median',
                                                'stockgrantvalue':'median', 'bonus':'median'  })
fb_levels_df
# Out:
#                            totalyearlycompensation  basesalary  \
# level
# E3                                           157.0       120.0
# IC3                                          175.0       125.0
# IC4                                          220.0       151.5
# IC5                                          297.0       182.0
# IC6                                          385.0       216.0
# IC7                                          740.0       270.0
# L3                                           165.0       115.0
# L4                                           211.0       155.0
# L5                                           300.0       185.0
# L5                                           317.0       191.0
# L5 Product Growth Analyst                    280.0       190.0
# L6                                           464.0       220.0
# M1                                           412.0       210.0
# M2                                           665.5       265.0
# l4                                           220.0       148.0
#
#                            yearsofexperience  yearsatcompany  stockgrantvalue  \
# level
# E3                                       0.0             0.0             25.0
# IC3                                      2.0             1.0             30.0
# IC4                                      3.0             1.0             49.0
# IC5                                      7.5             2.0             88.0
# IC6                                     10.0             3.0            135.0
# IC7                                     10.0             4.0            400.0
# L3                                       0.0             0.0             25.0
# L4                                       3.0             1.0             41.0
# L5                                       7.0             1.0             81.0
# L5                                       4.0             1.5            102.5
# L5 Product Growth Analyst                8.0             2.0             62.0
# L6                                       8.0             5.0            200.0
# M1                                      10.0             4.0            144.0
# M2                                      13.5             1.0            331.0
# l4                                       5.0             2.0             50.0
#
#                            bonus
# level
# E3                          12.0
# IC3                         11.0
# IC4                         16.0
# IC5                         27.0
# IC6                         44.0
# IC7                         70.0
# L3                          15.0
# L4                          16.0
# L5                          29.0
# L5                          26.0
# L5 Product Growth Analyst   29.0
# L6                          44.0
# M1                          57.0
# M2                          69.5
# l4                          20.0

# %%
#Correcting L4 to IC4 as they have similar basesalary/bonus
fb_df.replace('L4', 'IC4', inplace=True)
fb_df.replace('I4', 'IC4', inplace=True)
#Correcting L5 to IC5 as they have similar basesalary/bonus
fb_df.replace('L5', 'IC5', inplace=True)
fb_df.replace('L5 Product Growth Analyst', 'IC5', inplace=True)
#Correcting L6 to IC6 as they have similar basesalary/bonus
fb_df.replace('L6', 'IC6', inplace=True)

# %%
fb_df.level.value_counts()
# Out:
# IC4    74
# IC5    52
# IC6    18
# IC3    16
# L3      3
# E3      3
# L5      2
# M2      2
# l4      1
# M1      1
# IC7     1
# Name: level, dtype: int64

# %%
#Correcting L3/E3 to IC3 as they have similar basesalary/bonus
fb_df.replace('L3', 'IC3', inplace=True)
fb_df.replace('E3', 'IC3', inplace=True)

# %%
fb_df.level.value_counts()
# Out:
# IC4    74
# IC5    52
# IC3    22
# IC6    18
# L5      2
# M2      2
# l4      1
# M1      1
# IC7     1
# Name: level, dtype: int64

# %%
#Correcting L5 to IC5 as they have similar basesalary/bonus
fb_df.replace('L5 ', 'IC5', inplace=True)
#Correcting l4 to IC4 as they have similar basesalary/bonus
fb_df.replace('l4', 'IC4', inplace=True)

# %%
fb_df.level.value_counts()
# Out:
# IC4    75
# IC5    54
# IC3    22
# IC6    18
# M2      2
# M1      1
# IC7     1
# Name: level, dtype: int64

# %%
#removed M1 and M2 both software engineer managers
fb_df = fb_df.drop(index=fb_df[fb_df['level'] == 'M1'].index)
fb_df = fb_df.drop(index=fb_df[fb_df['level'] == 'M2'].index)
#removed IC7 due to high stock value as it indictates upper manangement
fb_df = fb_df.drop(index=fb_df[fb_df['level'] == 'IC7'].index)

# %%
#comparing medians for insights on compareable levels
fb_levels_df = fb_df.groupby(['level']).agg({'totalyearlycompensation':'median', 'basesalary':'median', 'yearsofexperience':'median', 'yearsatcompany':'median',
                                                'stockgrantvalue':'median', 'bonus':'median'  })
fb_levels_df
# Out:
#        totalyearlycompensation  basesalary  yearsofexperience  yearsatcompany  \
# level
# IC3                      168.5       120.0                1.0             0.5
# IC4                      220.0       153.0                3.0             1.0
# IC5                      297.0       183.0                7.0             2.0
# IC6                      390.0       218.0               10.0             3.0
#
#        stockgrantvalue  bonus
# level
# IC3               30.0   12.0
# IC4               45.0   16.0
# IC5               87.0   27.0
# IC6              135.0   44.0

# %%
#placing each level in our categories based on similiar: basesalary/yearsofexperience/yearsatcompany/stockgrantvalue/bonus
fb_df.loc[fb_df.level == "IC3", "Category"] = "Entry"
fb_df.loc[fb_df.level == "IC4", "Category"] = "Entry"
fb_df.loc[fb_df.level == "IC5", "Category"] = "Mid"
fb_df.loc[fb_df.level == "IC6", "Category"] = "Senior"

# %%
fb_df
# Out:
#                 timestamp   company level           title  \
# 858   2018-06-17 11:39:38  Facebook   IC5  Data Scientist
# 971   2018-07-05 13:43:39  Facebook   IC5  Data Scientist
# 1666  2018-09-06 00:50:18  Facebook   IC4  Data Scientist
# 1864  2018-09-17 15:37:28  Facebook   IC5  Data Scientist
# 2766  2018-10-28 16:36:57  Facebook   IC3  Data Scientist
# ...                   ...       ...   ...             ...
# 59853 2021-07-26 13:28:11  Facebook   IC4  Data Scientist
# 60192 2021-07-28 22:39:30  Facebook   IC5  Data Scientist
# 61309 2021-08-06 11:08:11  Facebook   IC4  Data Scientist
# 62109 2021-08-12 21:54:41  Facebook   IC5  Data Scientist
# 62610 2021-08-16 22:19:48  Facebook   IC4  Data Scientist
#
#        totalyearlycompensation  yearsofexperience  yearsatcompany  \
# 858                      370.0                8.0            3.00
# 971                      225.0               11.0            6.00
# 1666                     200.0                5.0            0.25
# 1864                     240.0               10.0            1.00
# 2766                     193.0                1.0            0.00
# ...                        ...                ...             ...
# 59853                    304.0                9.0            3.00
# 60192                    265.0               11.0            2.00
# 61309                    302.0                9.0            3.00
# 62109                    334.0                4.0            2.00
# 62610                    233.0                2.0            2.00
#
#                     tag  basesalary  stockgrantvalue  bonus  gender  \
# 858                           190.0            140.0   40.0    Male
# 971                           155.0              NaN    NaN
# 1666     Infrastructure       150.0             35.0   15.0
# 1864         Full Stack       171.0             45.0   24.0
# 2766            ML / AI         NaN              NaN    NaN
# ...                 ...         ...              ...    ...     ...
# 59853  Data Engineering       161.0            125.0   18.0  Female
# 60192    Infrastructure       190.0             60.0   15.0    Male
# 61309  Data Engineering       161.0            125.0   16.0  Female
# 62109           General       182.0            125.0   27.0    Male
# 62610  Data Engineering       157.0             60.0   16.0    Male
#
#                 city state country Category
# 858          Seattle    WA      US      Mid
# 971       Menlo Park    CA      US      Mid
# 1666      Menlo Park    CA      US    Entry
# 1864         Seattle    WA      US      Mid
# 2766   San Francisco    CA      US    Entry
# ...              ...   ...     ...      ...
# 59853     Menlo Park    CA      US    Entry
# 60192     Menlo Park    CA      US      Mid
# 61309     Menlo Park    CA      US    Entry
# 62109       New York    NY      US      Mid
# 62610     Menlo Park    CA      US    Entry
#
# [169 rows x 16 columns]

# %%
#import dependency
import pymongo
from pymongo import MongoClient

# %%
#establish connection to pymongo
conn ="mongodb://127.0.0.1:27017/"
client = MongoClient(conn)
db = client.ds_salaries

# %%
collection = db.facebook
fb_df_dict = fb_df.to_dict("records")

# %%
collection.insert_many(fb_df_dict)

# %%
db.facebook.find_one()
# Out:
# {'_id': ObjectId('617c72c7f3513d0dc98561b5'),
#  'timestamp': datetime.datetime(2018, 6, 17, 11, 39, 38),
#  'company': 'Facebook',
#  'level': 'IC5',
#  'title': 'Data Scientist',
#  'totalyearlycompensation': 370.0,
#  'yearsofexperience': 8.0,
#  'yearsatcompany': 3.0,
#  'tag': '',
#  'basesalary': 190.0,
#  'stockgrantvalue': 140.0,
#  'bonus': 40.0,
#  'gender': 'Male',
#  'city': 'Seattle',
#  'state': 'WA',
#  'country': 'US',
#  'Category': 'Mid'}
